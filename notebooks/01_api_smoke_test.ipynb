# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
url = os.getenv("FLIGHT_API_URL")

payload = {
    "searchContext": "departure",  
    "ymd": "20230101",
    "startTime": "0000",
    "endTime": "2400",
    "loadType": "json",
    "depAirport": "RKSI"
}

headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://www.airportal.go.kr/airport/aircraftInfo.do",
    "X-Requested-With": "XMLHttpRequest",
    "Content-Type": "application/json;charset=UTF-8"
}

session = requests.Session()
session.get(url)  # 세션 쿠키 획득

res = session.post(url, json=payload, headers=headers)
print(res.status_code)
data = res.json()
# Out:
# 200

# %%
data = data['content']

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      start  end searchContext searchSort   ymd  ymd1  ymd2 startTime endTime  \
# 0        0    0          None       None  None  None  None      None    None
# 1        0    0          None       None  None  None  None      None    None
# 2        0    0          None       None  None  None  None      None    None
# 3        0    0          None       None  None  None  None      None    None
# 4        0    0          None       None  None  None  None      None    None
# ..     ...  ...           ...        ...   ...   ...   ...       ...     ...
# 355      0    0          None       None  None  None  None      None    None
# 356      0    0          None       None  None  None  None      None    None
# 357      0    0          None       None  None  None  None      None    None
# 358      0    0          None       None  None  None  None      None    None
# 359      0    0          None       None  None  None  None      None    None
#
#     loadType  ... statusRemarkCode      img      alKr sDate actualFlightTime  \
# 0       None  ...                   ups.gif  유피에스화물항공  None            00:01
# 1       None  ...               RA  cks.gif   칼리타화물항공  None            00:46
# 2       None  ...                   kal.gif      대한항공  None            00:33
# 3       None  ...                   thy.gif      터키항공  None            00:19
# 4       None  ...                   kal.gif      대한항공  None            00:25
# ..       ...  ...              ...      ...       ...   ...              ...
# 355     None  ...                   fin.gif     핀란드항공  None            23:18
# 356     None  ...                   AIH.gif      에어제타  None            23:16
# 357     None  ...                   kal.gif      대한항공  None            23:33
# 358     None  ...                   kal.gif      대한항공  None            23:38
# 359     None  ...                   uae.gif   에미레이트항공  None            23:51
#
#      expectedFlightTime  schTime viewYn viewYnDesc nature
# 0                 23:25    00:05   None       None     화물
# 1                 00:30    00:05   None       None     화물
# 2                 23:20    00:10   None       None     화물
# 3                 00:15    00:15   None       None     여객
# 4                 00:20    00:20   None       None     화물
# ..                  ...      ...    ...        ...    ...
# 355               23:05    23:05   None       None     여객
# 356               23:10    23:10   None       None     화물
# 357               23:20    23:20   None       None     화물
# 358               23:30    23:30   None       None     화물
# 359               23:50    23:50   None       None     여객
#
# [360 rows x 33 columns]

# %%
len(df)
# Out:
# 360
